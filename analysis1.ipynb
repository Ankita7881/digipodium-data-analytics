# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = pd.read_excel('marksheet_faked.xlsx')
marks
# Out:
#     S.no   First name   Last name  DM  SE  GFX  DBMS  ECO
# 0      1     Sandhya        Singh  60  87   34    55   79
# 1      2       Pinki        Yadav  49  73   53    51   96
# 2      3      Ankita        Verma  77  77   96    93   79
# 3      4   Dipanjali        Singh  67  36   37    89   39
# 4      5      Khushi      Awasthi  34  90   59    33   47
# 5      6     Shalini          Pal  33  64   97    59   67
# 6      7      Saloni         Gond  60  64  100    97   37
# 7      8     Anushka   Srivastava  62  44   94    89   52
# 8      9       Aditi       Pandey  30  91   63   100   84
# 9     10       Umama        Anjum  84  38   37    92   86
# 10    11      Muskan        Singh  44  58   74    81   57
# 11    12       Kajal       Pandey  83  54   40    75   30
# 12    13     Anshika        Yadav  35  55   57    73   79
# 13    14     Deepika         Soni  69  87   99    82   75
# 14    15     Srishti      Kashyap  77  75   93    62   49
# ...

# %%
marks.set_index('First name', inplace = True)

# %%
marks['ECO'].plot(kind='bar',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}>

# %%
marks['DM'].plot(kind='bar',figsize=(7,3),title ='DM marks')
# Out:
# <Axes: title={'center': 'DM marks'}, xlabel='First name'>

# %%
marks['GFX'].plot(kind='pie',figsize=(10,5),title ='GFX marks')
# Out:
# <Axes: title={'center': 'GFX marks'}, ylabel='GFX'>

# %%
marks['DBMS'].plot(kind='line',figsize=(10,5),title ='DBMS marks')
# Out:
# <Axes: title={'center': 'DBMS marks'}, xlabel='First name'>

# %%
marks['ECO'].plot(kind='area',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, xlabel='First name'>

# %%
marks['SE'].plot(kind='pie',figsize=(10,5),title ='SE marks')
# Out:
# <Axes: title={'center': 'SE marks'}, ylabel='SE'>

# %%
marks['ECO'].plot(kind='hist',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, ylabel='Frequency'>

# %%
marks[['ECO','GFX']].plot(kind='bar',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, xlabel='First name'>

# %%
marks[['DM','GFX','SE','DBMS','ECO']].plot(kind='line',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, xlabel='First name'>

# %%
marks[['DM','GFX','SE','DBMS','ECO']].plot(kind='hist',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, ylabel='Frequency'>

# %%
marks[['DM','GFX','SE','DBMS','ECO']].plot(kind='area',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, xlabel='First name'>

# %%
marks[['DM','GFX','SE','DBMS','ECO']].plot(kind='bar',figsize=(10,5),title ='ECO marks')
# Out:
# <Axes: title={'center': 'ECO marks'}, xlabel='First name'>
