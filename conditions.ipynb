# %%
x=100

# %%
if x>10:
    print("x is greater than 10")
# Out:
# x is greater than 10

# %%
name = 'ankita verma'

# %%
'anki' in name
# Out:
# True

# %%
if 'ver' in name:
    print('ver found in name')
# Out:
# ver found in name

# %%
if 'vermaa' in name:
    print('ver found in name')

# %%
age = int(input('what is your age :'))
if age>=18:
    print('you are an adult')
    print('you can vote')
else:
    print('you are a child')
    print('you cannot vote')
    print('you can vote in',18-age,'years')
# Out:
# you are an adult
# you can vote

# %%
# if elif else ladder
print('welcome to the ice cream shop 🧁')
flavour = input('what flavour do you want ?')
if flavour== 'vanilla':
    print('here is your vanilla ice cream 🧁')
elif flavour == 'chocolate':
    print('here is your chocolate ice cream 🧁')
elif flavour == 'strawberry':
    print('here is your strawberry ice cream 🧁')
elif flavour == 'butterscoth':
    print('here is your butterscoth ice cream 🧁')
else:
    print('sorry we do not have', flavour,'flavour')
# Out:
# welcome to the ice cream shop
# here is your chocolate ice cream
